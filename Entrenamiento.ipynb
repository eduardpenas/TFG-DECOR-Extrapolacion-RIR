# %%
# !git clone https://github.com/eduardpenas/TFG-DECOR-Extrapolacion-RIR
# Out:
# Cloning into 'TFG-DECOR-Extrapolacion-RIR'...
# remote: Enumerating objects: 4481, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 4481 (delta 15), reused 36 (delta 14), pack-reused 4441 (from 2)
# Receiving objects: 100% (4481/4481), 106.13 MiB | 25.58 MiB/s, done.
# Resolving deltas: 100% (263/263), done.

# %%
# Instalar dependencias
# !pip3 install -r requirements.txt

# %%
# !python scripts/train.py --data-root /content/drive/MyDrive/Proyecto_BIRD/BIRD/Bird --epochs 1 --batch-size 128 --lr 1e-4 --latent-dim 128 --loss-alpha 0.0 --loss-beta 1.0 --val-ratio 0.1 --seed 42 --num-workers 2 --grad-clip 1.0 --checkpoint /dev/null
# Out:
# Dispositivo: cuda
# Época 1/1:   4% 10/282 [00:45<20:28,  4.52s/it, edc_l1=0.61997, gnorm=303.00, l1=0.00121, loss=32.73458, mrstft=32.73458]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 732, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1434, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/queue.py", line 180, in get
# ...

# %%
# Out:
# ^C
